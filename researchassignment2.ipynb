// %% [markdown]
// ## Research assignment 2
//
// Alisha Jones
//
// Skin color discrimination and life satisfaction
//
// Feb 19, 2020

// %%
### 1. Write a paragraph about your hypotheses

[Your answer here should explain:
1. What are your dependent variables? Why do they interest you? 
2. What are your independent variables? What direction to you hypothesize will be the relationship between your dependent variable and your dependent variables?
3. Why do you think your dependent variables are associated with your independent variables?
4. What are your control variables? Do you think they will show any spurious, intervening, or interactive relationships? Why?]
// Out:
// Unknown #command
// [ is not a valid command name
// r(199);
// r(199);

// %%
In this research project my dependent variable is satisfaction with life as a whole.
They are of interest to me because I think it is intresting to understnd how skin color discrimination influences individuals lives.
My independent variables is how often White people treat you badly becasue of skin shade and how often Black people treat you badly becasue of skin shade. 
I believe that my independent varibales and my dependent variables are associated because I believe that skin color discrimination or colorism has a huge influence on the life outcomes and life satisfaction.
I will also be controlling for gender and age.
I think that my control variables will show an intervening relationship.  
Overall I hypothesize that skin color discrimination will negatively influence the overall satisfaction with individuals lives. I also think that women will also be more negatively impacted by skin color discrimination than men.

// %% [markdown]
// ### 1. Setting up your session
//
// In the code cell below, do the following:
//
// 1. set current directory
// 2. set more off
// 3. create log file
// 4. download the data from its source if it's available online
// 5. read the data in [preferably only variables you are going to use]

// %%
set more off
capture log close
log using assignment2_log.log
// Out:
// file /Users/Alisha/Desktop/Gradstats/gradstats2/week4/assignment2_log.log already exists
// r(602);
// r(602);

// %%
use "20240-0003-Data.dta", clear
// Out:
// (Collaborative Psychiatric Epidemiology Surveys (CPES), 2001-2003 [United States])

// %% [markdown]
// ### 2. Browse the data
//
// Do the following in separate cells. Do do these in separate cells, you will need to use the right click "split cell" option:
//
// 1. Use "describe" to print details about the dataset
// 2. Print the heads and tables of the data using the appropriate magic
// 3. label the unique identifier variable
// 4. Generate a frequency table to show the N for each unit of time if there is data for multiple units in time
// 5. Check for missing data overall and within key categories of analysis (time, independent or dependent variable categories, etc)
// 6. use summarize to create a table with summary statistics for each variable you plan to analyze

// %%
describe
// Out:
// Contains data from 20240-0003-Data.dta
//   obs:         6,082                          Collaborative Psychiatric Epidemiology Surveys (CPES), 2001-2003 [United States]
//  vars:         3,031                          3 Apr 2008 10:42
// ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
//               storage   display    value
// variable name   type    format     label      variable label
// ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
// CASEID          int     %8.0g                 CASE IDENTIFICATION NUMBER
// ICD_HYP         int     %12.0g     ICD_HYP    ICD Hypomania (Lifetime)
// ICD_MDEH        int     %12.0g     ICD_MDEH   ICD Severe Depressive Episode w/ hierarchy (LifeT)
// DSM_BIPOLARII   int     %12.0g     DSM_BIPOLARII
//                                               DSM-IV Bi-Polar II (Lifetime)
// DSM_BIPOLARSUB  int     %12.0g     DSM_BIPOLARSUB
//                                               Lifetime Bi-Polar Subthreshold
// DSM_HYP         int     %12.0g     DSM_HYP    DSM-IV Hypomania (Lifetime)
// BIPOLARII_OND   int     %9.0g      BIPOLARII_OND
//                                               DSM-IV Bi-Polar II Onset
// BIPOLARII_RECD  int     %9.0g      BIPOLARII_RECD
//                                               DSM-IV Bi-Polar II Recency
// BIPOLARSUB_OND  int     %9.0g      BIPOLARSUB_OND
//                                               DSM-IV Bi-Polar Subthreshold Onset
// BIPOLARSUB_RECD int     %9.0g      BIPOLARSUB_RECD
//                                               DSM-IV Bi-Polar Subthreshold Recency
// DSM_MDDH        int     %12.0g     DSM_MDDH   DSM-IV Major Depressive Disorder w/ hierarchy (LifeT)
// MDDH_OND        int     %9.0g      MDDH_OND   DSM-IV Major Depressive Disorder w/ hierarchy Onset
// MDDH_RECD       int     %9.0g      MDDH_RECD
//                                               DSM-IV Major Depression w/ hierarchy Recency
// ICD_DYSH        int     %12.0g     ICD_DYSH   ICD Dysthymia w/ hierarchy (Lifetime)
// DSM_PAT         int     %12.0g     DSM_PAT    DSM-IV Panic Attack (Lifetime)
// ICD_PAT         int     %12.0g     ICD_PAT    ICD Panic Attack (Lifetime)
// PAT_OND         int     %9.0g      PAT_OND    DSM-IV Panic Attack Onset
// PAT_ONI         int     %9.0g      PAT_ONI    ICD Panic Attack Onset
// PAT_RECI        int     %9.0g      PAT_RECI   ICD Panic Attack Recency
// DSM_PDS         int     %12.0g     DSM_PDS    DSM-IV Panic Disorder (Lifetime)
// DSM_GADH        int     %12.0g     DSM_GADH   DSM-IV Gen Anxiety Disorder w/hierarchy (LifeT)
// DSM_ODDH        int     %12.0g     DSM_ODDH   DSM-IV Oppositionl Defiant Disorder w/ hierarchy (LifeT)
// I_MDEH12        int     %12.0g     I_MDEH12   ICD Severe Depressive Episode w/ hierarchy (12Mo)
// D_HYP12         int     %12.0g     D_HYP12    DSM-IV Hypomania (12 month)
// I_HYP12         int     %12.0g     I_HYP12    ICD Hypomania (12 month)
// D_BIPOLARII12   int     %12.0g     D_BIPOLARII12
//                                               DSM-IV Bi-polar II (12Mo)
// D_BIPOLARSUB12  int     %12.0g     D_BIPOLARSUB12
//                                               DSM-IV Bi-Polar Subthreshold (12Mo)
// I_DYSH12        int     %12.0g     I_DYSH12   ICD Dysthymia with hierarchy (12 month)
// I_CDH12         int     %12.0g     I_CDH12    ICD Conduct Disorder w/ hierarchy (12Mo)
// D_GADH12        int     %12.0g     D_GADH12   DSM-IV Gen Anxiety Disorder w/hierarchy (12Mo)
// I_PDS12         int     %12.0g     I_PDS12    ICD Panic Disorder (12 month)
// D_ALAH12        int     %12.0g     D_ALAH12   DSM-IV Alcohol Abuse w/ hierarchy (12Mo)
// D_HYP30         int     %12.0g     D_HYP30    DSM-IV Hypomania (30 day)
// D_BIPOLARSUB30  int     %12.0g     D_BIPOLARSUB30
//                                               DSM-IV Bi-Polar Subthreshold (30Day)
// I_PDS30         int     %12.0g     I_PDS30    ICD Panic Disorder (30 day)
// NEWCARESCORE    double  %10.0g                WHODAS self-care score
// NEWCOGSCORE     double  %10.0g                WHODAS cognitive score
// NEWMOVESCORE    double  %10.0g                WHODAS mobility score
// NEWOUTROLESCORE double  %10.0g                WHODAS time out of role score
// NEWROLEIMPSCORE double  %10.0g                WHODAS role impairment score
// NEWSOCIALSCORE  double  %10.0g                WHODAS social interaction score
// A1              int     %21.0g     A1         Satisfaction w/ life as a whole
// A2              int     %20.0g     A2         Frequency of visits w/ neighbors
// A3              int     %13.0g     A3         Frequency of crime in neighborhood
// A4              int     %18.0g     A4         Seriousness of drug probs in neighborhood
// A5              int     %9.0g      A5         There are clubs/associations/help groups in neighborhood
// A5A             int     %9.0g      A5A        Involved w/ any block clubs/assoc/groups in neighborhood
// A6A             int     %9.0g      A6A        Park/playgrounds/open space in neighborhood
// A6B             int     %9.0g      A6B        Supermarket in neighborhood
// A6C             int     %9.0g      A6C        Medical clinic in neighborhood
// A6D             int     %9.0g      A6D        Bank/credit union in neighborhood
// A6E             int     %9.0g      A6E        Check cashing outlet in neighborhood
// A6F             int     %9.0g      A6F        Police station in neighborhood
// A6G             int     %9.0g      A6G        Library in neighborhood
// B2              int     %9.0g      B2         Ever attended church services since 18 years or older
// B3              int     %41.0g     B3         Frequency attend religious services
// B4              int     %8.0g                 # hrs spent at church in typical weekend
// B5              int     %9.0g      B5         Official member of church
// B6              int     %20.0g     B6         Frequency take part in other church activities
// B7              int     %8.0g                 Hrs/week at place of worship not incl service
// B8              int     %20.0g     B8         Frequency see/write/phone church members
// B9              int     %10.0g     B9         # church people help you if needed
// B10             int     %26.0g     B10        Frequency church people help you out
// B11             int     %26.0g     B11        Frequency you help church people
// B12             int     %16.0g     B12        Closeness to church people
// B13             int     %21.0g     B13        Satisfaction w/ quality of relations w/ church people
// B14A            int     %13.0g     B14A       Church people make you feel loved
// B14B            int     %13.0g     B14B       Church people listen to problems
// B14C            int     %13.0g     B14C       Church people express interest in well-being
// B15A            int     %13.0g     B15A       Church people make too many demands on you
// B15B            int     %13.0g     B15B       Church people criticize you
// B15C            int     %13.0g     B15C       Church people take advantage of you
// B16A            int     %21.0g     B16A       Frequency read religious books/materials
// B16B            int     %21.0g     B16B       Frequency watch religious tv programs
// B16C            int     %21.0g     B16C       Frequency listen to religious programs on radio
// B16D            int     %21.0g     B16D       Frequency of praying
// B16E            int     %21.0g     B16E       Frequency of asking someone to pray for you
// B17A            int     %20.0g     B17A       Importance of religion in home when growing up
// B17B            int     %20.0g     B17B       Importance of parents taking kids to religious serv
// B17C            int     %20.0g     B17C       Importance of religion in your life
// B17D            int     %20.0g     B17D       Importance of spirituality in your life
// B17E            int     %20.0g     B17E       Importance of prayer in dealing w/ stressful situations
// --more--

// %%
%head G10A G10B A1 SEX AGE
// Out:
//      +----------------------------------------------------------------------+
//      |          G10A            G10B                      A1      SEX   AGE |
//      |----------------------------------------------------------------------|
//   1. |         NEVER           NEVER          VERY SATISFIED     MALE    19 |
//   2. | NOT TOO OFTEN   NOT TOO OFTEN      SOMEWHAT SATISFIED     MALE    50 |
//   3. |   HARDLY EVER     HARDLY EVER          VERY SATISFIED     MALE    26 |
//   4. |         NEVER           NEVER      SOMEWHAT SATISFIED   FEMALE    23 |
//   5. |  FAIRLY OFTEN   NOT TOO OFTEN          VERY SATISFIED   FEMALE    51 |
//      |----------------------------------------------------------------------|
//   6. | NOT TOO OFTEN   NOT TOO OFTEN      SOMEWHAT SATISFIED     MALE    50 |
//   7. |    VERY OFTEN    FAIRLY OFTEN       VERY DISSATISFIED     MALE    30 |
//   8. |             .               .          VERY SATISFIED     MALE    69 |
//   9. |   HARDLY EVER           NEVER   SOMEWHAT DISSATISFIED   FEMALE    30 |
//  10. |   HARDLY EVER     HARDLY EVER          VERY SATISFIED     MALE    45 |
//      +----------------------------------------------------------------------+

// %%
%tail G10A G10B A1 SEX AGE
// Out:
//       +----------------------------------------------------------------------+
//       |          G10A            G10B                      A1      SEX   AGE |
//       |----------------------------------------------------------------------|
// 6073. |  FAIRLY OFTEN           NEVER          VERY SATISFIED     MALE    37 |
// 6074. | NOT TOO OFTEN   NOT TOO OFTEN   SOMEWHAT DISSATISFIED   FEMALE    28 |
// 6075. | NOT TOO OFTEN     HARDLY EVER      SOMEWHAT SATISFIED     MALE    25 |
// 6076. |             .               .   SOMEWHAT DISSATISFIED     MALE    39 |
// 6077. | NOT TOO OFTEN           NEVER   SOMEWHAT DISSATISFIED     MALE    27 |
//       |----------------------------------------------------------------------|
// 6078. |         NEVER           NEVER      SOMEWHAT SATISFIED     MALE    21 |
// 6079. |         NEVER           NEVER   SOMEWHAT DISSATISFIED   FEMALE    20 |
// 6080. | NOT TOO OFTEN       DONT KNOW          VERY SATISFIED     MALE    41 |
// 6081. |    VERY OFTEN   NOT TOO OFTEN      SOMEWHAT SATISFIED   FEMALE    47 |
// 6082. |         NEVER           NEVER   SOMEWHAT DISSATISFIED     MALE    28 |
//       +----------------------------------------------------------------------+

// %%
%browse G10A G10B A1 SEX AGE
// Out:
//      +-------------------------------------------------------+
//      |          G10A            G10B                      A1 |
//      |-------------------------------------------------------|
//   1. |         NEVER           NEVER          VERY SATISFIED |
//   2. | NOT TOO OFTEN   NOT TOO OFTEN      SOMEWHAT SATISFIED |
//   3. |   HARDLY EVER     HARDLY EVER          VERY SATISFIED |
//   4. |         NEVER           NEVER      SOMEWHAT SATISFIED |
//   5. |  FAIRLY OFTEN   NOT TOO OFTEN          VERY SATISFIED |
//      |-------------------------------------------------------|
//   6. | NOT TOO OFTEN   NOT TOO OFTEN      SOMEWHAT SATISFIED |
//   7. |    VERY OFTEN    FAIRLY OFTEN       VERY DISSATISFIED |
//   8. |             .               .          VERY SATISFIED |
//   9. |   HARDLY EVER           NEVER   SOMEWHAT DISSATISFIED |
//  10. |   HARDLY EVER     HARDLY EVER          VERY SATISFIED |
//      |-------------------------------------------------------|
//  11. |         NEVER           NEVER      SOMEWHAT SATISFIED |
//  12. | NOT TOO OFTEN   NOT TOO OFTEN      SOMEWHAT SATISFIED |
//  13. |   HARDLY EVER     HARDLY EVER       VERY DISSATISFIED |
//  14. |         NEVER           NEVER      SOMEWHAT SATISFIED |
//  15. |   HARDLY EVER           NEVER          VERY SATISFIED |
//      |-------------------------------------------------------|
//  16. | NOT TOO OFTEN   NOT TOO OFTEN      SOMEWHAT SATISFIED |
//  17. | NOT TOO OFTEN     HARDLY EVER      SOMEWHAT SATISFIED |
//  18. |   HARDLY EVER   NOT TOO OFTEN   SOMEWHAT DISSATISFIED |
//  19. |   HARDLY EVER           NEVER      SOMEWHAT SATISFIED |
//  20. |     DONT KNOW     HARDLY EVER      SOMEWHAT SATISFIED |
//      |-------------------------------------------------------|
//  21. |   HARDLY EVER     HARDLY EVER      SOMEWHAT SATISFIED |
//  22. |   HARDLY EVER     HARDLY EVER   SOMEWHAT DISSATISFIED |
//  23. |         NEVER           NEVER          VERY SATISFIED |
//  24. | NOT TOO OFTEN     HARDLY EVER      SOMEWHAT SATISFIED |
//  25. |     DONT KNOW           NEVER      SOMEWHAT SATISFIED |
//      |-------------------------------------------------------|
//  26. | NOT TOO OFTEN     HARDLY EVER      SOMEWHAT SATISFIED |
//  27. |   HARDLY EVER           NEVER          VERY SATISFIED |
//  28. |   HARDLY EVER     HARDLY EVER      SOMEWHAT SATISFIED |
//  29. |   HARDLY EVER     HARDLY EVER      SOMEWHAT SATISFIED |
//  30. |   HARDLY EVER   NOT TOO OFTEN          VERY SATISFIED |
//      |-------------------------------------------------------|
//  31. |  FAIRLY OFTEN    FAIRLY OFTEN      SOMEWHAT SATISFIED |
//  32. |         NEVER           NEVER      SOMEWHAT SATISFIED |
//  33. |         NEVER           NEVER      SOMEWHAT SATISFIED |
//  34. |         NEVER           NEVER      SOMEWHAT SATISFIED |
//  35. |   HARDLY EVER     HARDLY EVER          VERY SATISFIED |
//      |-------------------------------------------------------|
//  36. |   HARDLY EVER           NEVER          VERY SATISFIED |
//  37. |  FAIRLY OFTEN    FAIRLY OFTEN      SOMEWHAT SATISFIED |
//  38. | NOT TOO OFTEN           NEVER   SOMEWHAT DISSATISFIED |
//  39. |         NEVER           NEVER      SOMEWHAT SATISFIED |
//  40. |         NEVER           NEVER          VERY SATISFIED |
//      |-------------------------------------------------------|
//  41. |         NEVER           NEVER          VERY SATISFIED |
//  42. |  FAIRLY OFTEN      VERY OFTEN   SOMEWHAT DISSATISFIED |
//  43. |   HARDLY EVER     HARDLY EVER          VERY SATISFIED |
//  44. | NOT TOO OFTEN           NEVER          VERY SATISFIED |
//  45. |    VERY OFTEN    FAIRLY OFTEN          VERY SATISFIED |
//      |-------------------------------------------------------|
//  46. |         NEVER           NEVER          VERY SATISFIED |
//  47. | NOT TOO OFTEN   NOT TOO OFTEN          VERY SATISFIED |
//  48. |  FAIRLY OFTEN   NOT TOO OFTEN      SOMEWHAT SATISFIED |
//  49. |         NEVER           NEVER      SOMEWHAT SATISFIED |
//  50. |    VERY OFTEN   NOT TOO OFTEN      SOMEWHAT SATISFIED |
//      |-------------------------------------------------------|
//  51. |   HARDLY EVER     HARDLY EVER          VERY SATISFIED |
//  52. |  FAIRLY OFTEN   NOT TOO OFTEN      SOMEWHAT SATISFIED |
//  53. |    VERY OFTEN           NEVER      SOMEWHAT SATISFIED |
//  54. | NOT TOO OFTEN     HARDLY EVER       VERY DISSATISFIED |
//  55. | NOT TOO OFTEN     HARDLY EVER      SOMEWHAT SATISFIED |
//      |-------------------------------------------------------|
//  56. | NOT TOO OFTEN           NEVER          VERY SATISFIED |
//  57. | NOT TOO OFTEN           NEVER   SOMEWHAT DISSATISFIED |
//  58. |   HARDLY EVER           NEVER      SOMEWHAT SATISFIED |
//  59. |   HARDLY EVER           NEVER      SOMEWHAT SATISFIED |
//  60. |   HARDLY EVER     HARDLY EVER      SOMEWHAT SATISFIED |
//      |-------------------------------------------------------|
//  61. |  FAIRLY OFTEN           NEVER      SOMEWHAT SATISFIED |
//  62. |    VERY OFTEN           NEVER          VERY SATISFIED |
//  63. |         NEVER           NEVER      SOMEWHAT SATISFIED |
//  64. | NOT TOO OFTEN           NEVER          VERY SATISFIED |
//  65. |    VERY OFTEN           NEVER          VERY SATISFIED |
//      |-------------------------------------------------------|
//  66. |   HARDLY EVER           NEVER          VERY SATISFIED |
//  67. |   HARDLY EVER     HARDLY EVER          VERY SATISFIED |
//  68. |         NEVER           NEVER      SOMEWHAT SATISFIED |
//  69. |    VERY OFTEN    FAIRLY OFTEN      SOMEWHAT SATISFIED |
//  70. |   HARDLY EVER     HARDLY EVER      SOMEWHAT SATISFIED |
//      |-------------------------------------------------------|
//  71. |   HARDLY EVER   NOT TOO OFTEN      SOMEWHAT SATISFIED |
//  72. |   HARDLY EVER     HARDLY EVER      SOMEWHAT SATISFIED |
//  73. |         NEVER           NEVER      SOMEWHAT SATISFIED |
//  74. | NOT TOO OFTEN     HARDLY EVER          VERY SATISFIED |
//  75. | NOT TOO OFTEN   NOT TOO OFTEN      SOMEWHAT SATISFIED |
//      |-------------------------------------------------------|
//  76. |   HARDLY EVER     HARDLY EVER          VERY SATISFIED |
//  77. |         NEVER    FAIRLY OFTEN      SOMEWHAT SATISFIED |
//  78. |         NEVER           NEVER      SOMEWHAT SATISFIED |
//  79. |  FAIRLY OFTEN           NEVER      SOMEWHAT SATISFIED |
//  80. | NOT TOO OFTEN   NOT TOO OFTEN      SOMEWHAT SATISFIED |
//      |-------------------------------------------------------|
//  81. | NOT TOO OFTEN     HARDLY EVER      SOMEWHAT SATISFIED |
//  82. |         NEVER           NEVER          VERY SATISFIED |
//  83. |         NEVER           NEVER          VERY SATISFIED |
//  84. |         NEVER           NEVER      SOMEWHAT SATISFIED |
//  85. | NOT TOO OFTEN   NOT TOO OFTEN          VERY SATISFIED |
//      |-------------------------------------------------------|
//  86. | NOT TOO OFTEN           NEVER   SOMEWHAT DISSATISFIED |
//  87. | NOT TOO OFTEN   NOT TOO OFTEN   SOMEWHAT DISSATISFIED |
//  88. | NOT TOO OFTEN           NEVER   SOMEWHAT DISSATISFIED |
//  89. |    VERY OFTEN    FAIRLY OFTEN       VERY DISSATISFIED |
//  90. | NOT TOO OFTEN           NEVER      SOMEWHAT SATISFIED |
//      |-------------------------------------------------------|
//  91. |         NEVER           NEVER          VERY SATISFIED |
//  92. | NOT TOO OFTEN           NEVER      SOMEWHAT SATISFIED |
//  93. |         NEVER           NEVER   SOMEWHAT DISSATISFIED |
//  94. |             .               .          VERY SATISFIED |
//  95. |             .               .       VERY DISSATISFIED |
//      |-------------------------------------------------------|
//  96. |             .               .      SOMEWHAT SATISFIED |
//  97. | NOT TOO OFTEN     HARDLY EVER          VERY SATISFIED |
//  98. |             .               .   SOMEWHAT DISSATISFIED |
//  99. |             .               .          VERY SATISFIED |
// 100. |         NEVER           NEVER          VERY SATISFIED |
//      |-------------------------------------------------------|
// 101. | NOT TOO OFTEN   NOT TOO OFTEN          VERY SATISFIED |
// 102. |             .               .      SOMEWHAT SATISFIED |
// 103. |             .               .      SOMEWHAT SATISFIED |
// 104. |             .               .      SOMEWHAT SATISFIED |
// 105. |             .               .          VERY SATISFIED |
//      |-------------------------------------------------------|
// 106. |             .               .      SOMEWHAT SATISFIED |
// 107. |             .               .   SOMEWHAT DISSATISFIED |
// 108. |   HARDLY EVER     HARDLY EVER      SOMEWHAT SATISFIED |
// 109. |             .               .          VERY SATISFIED |
// 110. |   HARDLY EVER     HARDLY EVER      SOMEWHAT SATISFIED |
//      |-------------------------------------------------------|
// 111. |             .               .          VERY SATISFIED |
// 112. |  FAIRLY OFTEN    FAIRLY OFTEN      SOMEWHAT SATISFIED |
// 113. | NOT TOO OFTEN           NEVER      SOMEWHAT SATISFIED |
// 114. |    VERY OFTEN      VERY OFTEN       VERY DISSATISFIED |
// 115. |  FAIRLY OFTEN     HARDLY EVER   SOMEWHAT DISSATISFIED |
//      |-------------------------------------------------------|
// 116. |             .               .   SOMEWHAT DISSATISFIED |
// 117. |         NEVER           NEVER   SOMEWHAT DISSATISFIED |
// 118. | NOT TOO OFTEN     HARDLY EVER      SOMEWHAT SATISFIED |
// 119. |         NEVER           NEVER      SOMEWHAT SATISFIED |
// 120. |     DONT KNOW       DONT KNOW   SOMEWHAT DISSATISFIED |
//      |-------------------------------------------------------|
// 121. | NOT TOO OFTEN     HARDLY EVER   SOMEWHAT DISSATISFIED |
// 122. | NOT TOO OFTEN     HARDLY EVER      SOMEWHAT SATISFIED |
// 123. |    VERY OFTEN    FAIRLY OFTEN   SOMEWHAT DISSATISFIED |
// 124. |         NEVER           NEVER          VERY SATISFIED |
// 125. | NOT TOO OFTEN           NEVER          VERY SATISFIED |
//      |-------------------------------------------------------|
// 126. |    VERY OFTEN      VERY OFTEN          VERY SATISFIED |
// 127. |  FAIRLY OFTEN   NOT TOO OFTEN   SOMEWHAT DISSATISFIED |
// 128. |  FAIRLY OFTEN           NEVER          VERY SATISFIED |
// 129. |    VERY OFTEN   NOT TOO OFTEN      SOMEWHAT SATISFIED |
// 130. | NOT TOO OFTEN     HARDLY EVER      SOMEWHAT SATISFIED |
//      |-------------------------------------------------------|
// 131. |   HARDLY EVER     HARDLY EVER          VERY SATISFIED |
// 132. |         NEVER           NEVER      SOMEWHAT SATISFIED |
// 133. |  FAIRLY OFTEN           NEVER   SOMEWHAT DISSATISFIED |
// 134. |  FAIRLY OFTEN   NOT TOO OFTEN      SOMEWHAT SATISFIED |
// 135. | NOT TOO OFTEN   NOT TOO OFTEN      SOMEWHAT SATISFIED |
//      |-------------------------------------------------------|
// 136. | NOT TOO OFTEN   NOT TOO OFTEN      SOMEWHAT SATISFIED |
// 137. | NOT TOO OFTEN           NEVER   SOMEWHAT DISSATISFIED |
// 138. |  FAIRLY OFTEN   NOT TOO OFTEN      SOMEWHAT SATISFIED |
// 139. | NOT TOO OFTEN   NOT TOO OFTEN   SOMEWHAT DISSATISFIED |
// 140. |  FAIRLY OFTEN    FAIRLY OFTEN      SOMEWHAT SATISFIED |
//      |-------------------------------------------------------|
// 141. |             .               .      SOMEWHAT SATISFIED |
// 142. |   HARDLY EVER           NEVER          VERY SATISFIED |
// 143. |   HARDLY EVER     HARDLY EVER      SOMEWHAT SATISFIED |
// 144. |         NEVER           NEVER      SOMEWHAT SATISFIED |
// 145. | NOT TOO OFTEN           NEVER      SOMEWHAT SATISFIED |
//      |-------------------------------------------------------|
// 146. |             .               .      SOMEWHAT SATISFIED |
// 147. |         NEVER           NEVER      SOMEWHAT SATISFIED |
// 148. | NOT TOO OFTEN   NOT TOO OFTEN      SOMEWHAT SATISFIED |
// 149. | NOT TOO OFTEN   NOT TOO OFTEN   SOMEWHAT DISSATISFIED |
// 150. |         NEVER           NEVER      SOMEWHAT SATISFIED |
//      |-------------------------------------------------------|
// 151. |         NEVER           NEVER      SOMEWHAT SATISFIED |
// 152. |    VERY OFTEN   NOT TOO OFTEN      SOMEWHAT SATISFIED |
// 153. |   HARDLY EVER           NEVER      SOMEWHAT SATISFIED |
// 154. | NOT TOO OFTEN           NEVER      SOMEWHAT SATISFIED |
// 155. |  FAIRLY OFTEN     HARDLY EVER      SOMEWHAT SATISFIED |
//      |-------------------------------------------------------|
// 156. | NOT TOO OFTEN   NOT TOO OFTEN   SOMEWHAT DISSATISFIED |
// 157. |   HARDLY EVER     HARDLY EVER      SOMEWHAT SATISFIED |
// 158. | NOT TOO OFTEN           NEVER      SOMEWHAT SATISFIED |
// 159. |         NEVER           NEVER          VERY SATISFIED |
// 160. |             .               .      SOMEWHAT SATISFIED |
//      |-------------------------------------------------------|
// 161. |             .               .      SOMEWHAT SATISFIED |
// 162. | NOT TOO OFTEN   NOT TOO OFTEN      SOMEWHAT SATISFIED |
// 163. | NOT TOO OFTEN     HARDLY EVER      SOMEWHAT SATISFIED |
// 164. |  FAIRLY OFTEN      VERY OFTEN      SOMEWHAT SATISFIED |
// 165. |   HARDLY EVER           NEVER   SOMEWHAT DISSATISFIED |
//      |-------------------------------------------------------|
// 166. |    VERY OFTEN           NEVER      SOMEWHAT SATISFIED |
// 167. | NOT TOO OFTEN   NOT TOO OFTEN      SOMEWHAT SATISFIED |
// 168. |             .               .          VERY SATISFIED |
// 169. |  FAIRLY OFTEN     HARDLY EVER      SOMEWHAT SATISFIED |
// 170. |             .               .          VERY SATISFIED |
//      |-------------------------------------------------------|
// 171. | NOT TOO OFTEN           NEVER          VERY SATISFIED |
// 172. |     DONT KNOW       DONT KNOW      SOMEWHAT SATISFIED |
// 173. | NOT TOO OFTEN   NOT TOO OFTEN      SOMEWHAT SATISFIED |
// 174. |  FAIRLY OFTEN     HARDLY EVER      SOMEWHAT SATISFIED |
// 175. |         NEVER           NEVER      SOMEWHAT SATISFIED |
//      |-------------------------------------------------------|
// 176. |   HARDLY EVER     HARDLY EVER      SOMEWHAT SATISFIED |
// 177. |  FAIRLY OFTEN   NOT TOO OFTEN   SOMEWHAT DISSATISFIED |
// 178. |             .               .   SOMEWHAT DISSATISFIED |
// 179. | NOT TOO OFTEN   NOT TOO OFTEN          VERY SATISFIED |
// 180. |   HARDLY EVER           NEVER      SOMEWHAT SATISFIED |
//      |-------------------------------------------------------|
// 181. |  FAIRLY OFTEN    FAIRLY OFTEN      SOMEWHAT SATISFIED |
// 182. |             .               .          VERY SATISFIED |
// 183. |    VERY OFTEN    FAIRLY OFTEN       VERY DISSATISFIED |
// 184. |   HARDLY EVER           NEVER      SOMEWHAT SATISFIED |
// 185. | NOT TOO OFTEN   NOT TOO OFTEN      SOMEWHAT SATISFIED |
//      |-------------------------------------------------------|
// 186. | NOT TOO OFTEN    FAIRLY OFTEN   SOMEWHAT DISSATISFIED |
// 187. |  FAIRLY OFTEN           NEVER      SOMEWHAT SATISFIED |
// 188. |       REFUSED         REFUSED      SOMEWHAT SATISFIED |
// 189. | NOT TOO OFTEN   NOT TOO OFTEN      SOMEWHAT SATISFIED |
// 190. | NOT TOO OFTEN   NOT TOO OFTEN       VERY DISSATISFIED |
//      |-------------------------------------------------------|
// 191. |  FAIRLY OFTEN   NOT TOO OFTEN      SOMEWHAT SATISFIED |
// 192. | NOT TOO OFTEN   NOT TOO OFTEN   SOMEWHAT DISSATISFIED |
// 193. |         NEVER           NEVER      SOMEWHAT SATISFIED |
// 194. |         NEVER           NEVER   SOMEWHAT DISSATISFIED |
// 195. |    VERY OFTEN     HARDLY EVER          VERY SATISFIED |
//      |-------------------------------------------------------|
// 196. |    VERY OFTEN           NEVER      SOMEWHAT SATISFIED |
// 197. |   HARDLY EVER           NEVER      SOMEWHAT SATISFIED |
// 198. | NOT TOO OFTEN           NEVER      SOMEWHAT SATISFIED |
// 199. | NOT TOO OFTEN    FAIRLY OFTEN   SOMEWHAT DISSATISFIED |
// 200. | NOT TOO OFTEN           NEVER      SOMEWHAT SATISFIED |
//      +-------------------------------------------------------+

// %%
mdesc G10A G10B A1 SEX AGE
// Out:
//     Variable    |     Missing          Total     Percent Missing
// ----------------+-----------------------------------------------
//            G10A |         988          6,082          16.24
//            G10B |         978          6,082          16.08
//              A1 |           0          6,082           0.00
//             SEX |           0          6,082           0.00
//             AGE |           0          6,082           0.00
// ----------------+-----------------------------------------------

// %%
summarize G10A G10B A1 SEX AGE
// Out:
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//         G10A |      5,094    3.404005    1.223707          1          5
//         G10B |      5,104    3.870298    1.158947          1          5
//           A1 |      6,082    1.811575    .7238354          1          4
//          SEX |      6,082    1.624137    .4843848          1          2
//          AGE |      6,082    43.22246    16.33308         18         94

// %%
### 3. Write a note summarizing what you learned from browsing the data

After browsing the data I leanrned that there was some missing responses within my independent varibales, however I don't think 16% is a huge amount of missing data. I also learned that I have a pretty good number of observations to work with.

// %% [markdown]
// ### 4. Create univariate histograms of interval ratio variables you plan to analyze.
//
// Write at least 3 forloops to generate histograms for all the variables you plan to analyze. Create titles for each histogram that notes whether it is a dependent, independent, or control variable (you can also note in titles whether control vars control for spurious, intervening, or interactive relationships). Begin with your dependent variables. Then make a note below to describe the shapes of the distributions and their implications for your study.
//
// [your note here]

// %%
foreach var in A1 {
    histogram `var' if `var'<20000, title(dependent variable) name(`var', replace) bin(10)
}

foreach var in G10A {
    histogram `var' if `var'<20000, title(dependent variable) name(`var', replace) bin(10)
}

foreach var in G10B {
    histogram `var' if `var'<20000, title(dependent variable) name(`var', replace) bin(10)
}



order A1 G10A G10B

foreach x of var A1-G10B {
    histogram `x' if `x'<20000, title(dependent variable) name(`var', replace) bin(10)
}
// Out:
// (bin=10, start=1, width=.3)
// This front-end cannot display the desired image type.
// . foreach var in G10A {
// (bin=10, start=1, width=.4)
// This front-end cannot display the desired image type.
// . foreach var in G10B {
// (bin=10, start=1, width=.4)
// This front-end cannot display the desired image type.
// . order A1 G10A G10B
//
// (bin=10, start=1, width=.3)
// This front-end cannot display the desired image type.
// (bin=10, start=1, width=.4)
// This front-end cannot display the desired image type.
// (bin=10, start=1, width=.4)
// This front-end cannot display the desired image type.

// %% [markdown]
// ### 5. Create univariate count and % frequency tables for all categorical (nominal) variables you plan to analyze
//
// Again, use forloops. Then write a note below with a narrative summary of the distributions and their implications for your study.
//
// [your note here]

// %%
order SEX A1 G10A G10B

foreach x of var G10A-G10B {
    tab SEX `x' 
}
// Out:
//            |       Freq Whts treat R badly due to skin shade
//        Sex | VERY OFTE  FAIRLY OF  NOT TOO O  HARDLY EV      NEVER |     Total
// -----------+-------------------------------------------------------+----------
//       MALE |       206        288        577        425        377 |     1,873
//     FEMALE |       215        435        964        770        837 |     3,221
// -----------+-------------------------------------------------------+----------
//      Total |       421        723      1,541      1,195      1,214 |     5,094
//
//            |       Freq Blks treat R badly due to skin shade
//        Sex | VERY OFTE  FAIRLY OF  NOT TOO O  HARDLY EV      NEVER |     Total
// -----------+-------------------------------------------------------+----------
//       MALE |        71        150        451        439        766 |     1,877
//     FEMALE |       125        317        773        694      1,318 |     3,227
// -----------+-------------------------------------------------------+----------
//      Total |       196        467      1,224      1,133      2,084 |     5,104

// %%
# 6. Make a relevant bivariate table and graph for your study

Make the appropriate a) bivariate table and b) graph dependening on whether your dependent variable is nominal/categorical or interval ratio. If your dependent variable is nominal, make sure it is the row variable in the table. If your independent variable is interval ratio, convert it into an ordinal variable by creating a new variable with 3 to 5 categories each with an equal range of the interval ratio variable. Then use the new ordinal variable as your independent variable in the bivariate table and graph.

// %%
tab G10A A1 
tab G10B A1

graph bar G10A A1
graph bar G10B A1
// Out:
//     Freq Whts |
// treat R badly |
//   due to skin |       Satisfaction w/ life as a whole
//         shade | VERY SATI  SOMEWHAT   SOMEWHAT   VERY DISS |     Total
// --------------+--------------------------------------------+----------
//    VERY OFTEN |       150        183         59         29 |       421
//  FAIRLY OFTEN |       220        394         97         12 |       723
// NOT TOO OFTEN |       476        849        182         34 |     1,541
//   HARDLY EVER |       403        660        112         20 |     1,195
//         NEVER |       470        581        128         35 |     1,214
// --------------+--------------------------------------------+----------
//         Total |     1,719      2,667        578        130 |     5,094
//
//
//     Freq Blks |
// treat R badly |
//   due to skin |       Satisfaction w/ life as a whole
//         shade | VERY SATI  SOMEWHAT   SOMEWHAT   VERY DISS |     Total
// --------------+--------------------------------------------+----------
//    VERY OFTEN |        71         85         24         16 |       196
//  FAIRLY OFTEN |       149        230         73         15 |       467
// NOT TOO OFTEN |       387        667        141         29 |     1,224
//   HARDLY EVER |       366        635        111         21 |     1,133
//         NEVER |       746      1,059        231         48 |     2,084
// --------------+--------------------------------------------+----------
//         Total |     1,719      2,676        580        129 |     5,104
// This front-end cannot display the desired image type.
// This front-end cannot display the desired image type.

// %% [markdown]
// ### 7. Create partial bivariate tables and graphs
//
// For the bivariate table and graph you made for problem 6, split both into partial tables and graphs using one of your nominal/categorical control variables. If your control variable is interval ratio, convert it into an ordinal variable by creating a variable with 3 to 5 categories each with an equal range of the interval ratio variable.  Then use the new ordinal variable as your control variable to create the partial tables and graphs.

// %%
bysort SEX: tab G10A A1
bysort SEX: tab G10B A1

graph bar G10A A1, over(SEX)
graph bar G10B A1, over(SEX)
// Out:
// ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
// -> SEX = MALE
//
//     Freq Whts |
// treat R badly |
//   due to skin |       Satisfaction w/ life as a whole
//         shade | VERY SATI  SOMEWHAT   SOMEWHAT   VERY DISS |     Total
// --------------+--------------------------------------------+----------
//    VERY OFTEN |        71         97         27         11 |       206
//  FAIRLY OFTEN |        99        145         39          5 |       288
// NOT TOO OFTEN |       190        317         56         14 |       577
//   HARDLY EVER |       158        229         36          2 |       425
//         NEVER |       160        170         38          9 |       377
// --------------+--------------------------------------------+----------
//         Total |       678        958        196         41 |     1,873
//
// ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
// -> SEX = FEMALE
//
//     Freq Whts |
// treat R badly |
//   due to skin |       Satisfaction w/ life as a whole
//         shade | VERY SATI  SOMEWHAT   SOMEWHAT   VERY DISS |     Total
// --------------+--------------------------------------------+----------
//    VERY OFTEN |        79         86         32         18 |       215
//  FAIRLY OFTEN |       121        249         58          7 |       435
// NOT TOO OFTEN |       286        532        126         20 |       964
//   HARDLY EVER |       245        431         76         18 |       770
//         NEVER |       310        411         90         26 |       837
// --------------+--------------------------------------------+----------
//         Total |     1,041      1,709        382         89 |     3,221
//
//
//
// ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
// -> SEX = MALE
//
//     Freq Blks |
// treat R badly |
//   due to skin |       Satisfaction w/ life as a whole
//         shade | VERY SATI  SOMEWHAT   SOMEWHAT   VERY DISS |     Total
// --------------+--------------------------------------------+----------
//    VERY OFTEN |        27         32          8          4 |        71
//  FAIRLY OFTEN |        65         60         20          5 |       150
// NOT TOO OFTEN |       147        249         47          8 |       451
//   HARDLY EVER |       155        236         39          9 |       439
//         NEVER |       282        388         82         14 |       766
// --------------+--------------------------------------------+----------
//         Total |       676        965        196         40 |     1,877
//
// ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
// -> SEX = FEMALE
//
//     Freq Blks |
// treat R badly |
//   due to skin |       Satisfaction w/ life as a whole
//         shade | VERY SATI  SOMEWHAT   SOMEWHAT   VERY DISS |     Total
// --------------+--------------------------------------------+----------
//    VERY OFTEN |        44         53         16         12 |       125
//  FAIRLY OFTEN |        84        170         53         10 |       317
// NOT TOO OFTEN |       240        418         94         21 |       773
//   HARDLY EVER |       211        399         72         12 |       694
//         NEVER |       464        671        149         34 |     1,318
// --------------+--------------------------------------------+----------
//         Total |     1,043      1,711        384         89 |     3,227
// This front-end cannot display the desired image type.
// This front-end cannot display the desired image type.

// %% [markdown]
// ### Interpret of your bivariate and partial tables and graphs
//
// Is there a relationship between your dependent and independent variables? Is it weak, strong, or non-existent? Do adding controls reveal any spurious, intervening, or interactive relationships? Do they conform with your hypotheses? If not, do you have any ideas for why and how you might test the reason why?

// %%
I think that the relationship between my independent variables and my dependent variable is either weak or maybe even non-existent. There seems to be a relationship it just doesn't look like it's a strong one. I think that my control variable shows an interactive relationship. This did not actualy conform to my hypothesis. I think that maybe I need more and more relevant dependemt varibales in my model.
